# %% [markdown]
# # **Practical No.09**

# %% [markdown]
# ## **Roll No. 01**
# ## **Name : Pawan Gosavi**

# %% [markdown]
# ### **P9 - A**
#
# ### **Aim** : Try to configure the widget with various options like: `bg = "red", family = "times", size = 18.`

# %% [markdown]
# Since Google Colab runs on Virtual Servers. We Don't have any Monitor to Display it. so, we need to run this code on our Local Machine Python Interpreter. Copy the Code into Local Python Environment. Save it as "P9 - A.py", then run it. take screenshot of output by pressing "Alt + PrntScr" button on keyboard. save the output as "9A.png". then upload it here by pressing on "insert image".

# %%
# imports
import tkinter as tk
# from tkinter import ttk

# Create instance
win = tk.Tk()   

# Add a title       
win.title("PP Practical No. 09 A")

# Add a Canvas size
# win.geometry("300x300")

# Adding a Label
my_label = tk.Label(win, text = "Pawan Gosavi", bg = "red",
                 fg = "White", font=('times', 18), width = 25)
my_label.pack()

# Start GUI
win.mainloop()

# %% [markdown]
# **Output:**

# %% [markdown]
# ![P9 A.png](data:image/png;base64,...)

# %% [markdown]
# ### **P9 - B**
#
# ### **Aim** : Try to change the widget type and configuration options to experiment with other widget types like Message, Button, Entry, Checkbutton, Radiobutton, Scale etc.

# %% [markdown]
# Since Google Colab runs on Virtual Servers. We Don't have any Monitor to Display it. so, we need to run this code on our Local Machine Python Interpreter. Copy the Code into Local Python Environment. Save it as "P9 - B.py", then run it. take screenshot of output by pressing "Alt + PrntScr" button on keyboard. save the various phases of outputs as "9B1.png", "9B2.png", "9B3.png", "9B4.png" respectively. then upload it here by pressing on "insert image".

# %%
# imports
import tkinter as tk
# from tkinter import ttk

# Create instance
win = tk.Tk()   

# Add a title       
win.title('PP Practical No. 09 B')

# Add a size
win.geometry('400x600')

# Make it Non Resizeable
win.resizable(False, False)

# Adding a Message
my_message = tk.Message(win, text = 'Registration Form',
                        bg = 'White', fg = 'Red', font=('Comic Sans MS', 18),
                        relief = "solid", width = 300)
my_message.pack(pady = 5)

def submitform():
    fname = 'Name : ' + str(name.get())
    femail = 'Email : ' + str(email.get())
    fpass = 'Password : ' + str(password.get())
    fgender = 'Gender : ' + str(gender.get())
    fage = 'Age : ' + str(age.get())
    print("\nx--------- Registration Details ---------x\n")
    print(fname)
    print(femail)
    print(fpass)
    print(fgender)
    print(fage)
    print("\nx--------- Submission Successfull! ---------x\n")
    L6.config(text = 'Dear ' + str(name.get()) + ', Form Submitted Successfully!')
    E1.config(state = 'disabled')
    E2.config(state = 'disabled')
    E3.config(state = 'disabled')
    R1.config(state = 'disabled')
    R2.config(state = 'disabled')
    S1.config(state = 'disabled')
    C1.config(state = 'disabled')
    B1.config(state = 'disabled')
    
def tnc():
    ftandc = str(tandc.get())
    if ftandc == '1':
        B1.config(state = 'active')
    else:
        B1.config(state = 'disabled')

def rb():
    fgender = str(gender.get())
    if fgender == 'Male':
        R1.config(fg = 'Blue')
        R2.config(fg = 'Black')
    else:
        R2.config(fg = 'Blue')
        R1.config(fg = 'Black')

name = tk.StringVar()
email = tk.StringVar()
password = tk.StringVar()
tandc = tk.StringVar()
gender = tk.StringVar()
age = tk.StringVar()

# Adding a Labels
L1 = tk.Label(win, font=('Comic Sans MS', 12), text = 'Full Name')
L1.pack(pady = 3)

E1 = tk.Entry(win, textvariable = name, justify = 'center',
              bd = 2, width = 30, fg = 'Blue', font=('Comic Sans MS', 12))
E1.pack(pady = 3)

L2 = tk.Label(win, font=('Comic Sans MS', 12), text = 'Email')
L2.pack(pady = 3)

E2 = tk.Entry(win, textvariable = email, justify = 'center',
              bd = 2, width = 30, fg = 'Blue', font=('Comic Sans MS', 12))
E2.pack(pady = 3)

L3 = tk.Label(win, font=('Comic Sans MS', 12), text = 'Password')
L3.pack(pady = 3)

E3 = tk.Entry(win, textvariable = password, justify = 'center', show='*',
              bd = 2, width = 30, fg = 'Blue', font=('Comic Sans MS', 12))
E3.pack(pady = 3)

L4 = tk.Label(win, font=('Comic Sans MS', 12), text = 'Gender')
L4.pack(pady = 3)

R1 = tk.Radiobutton(win, text = 'Male', font=('Comic Sans MS', 12),
                    value = 'Male', variable = gender, command = rb)
R1.pack(pady = 3)

R2 = tk.Radiobutton(win, text = 'Female', font=('Comic Sans MS', 12),
                    value = 'Female', variable = gender, command = rb)
R2.pack(pady = 3)

L5 = tk.Label(win, font=('Comic Sans MS', 12), text = 'Age')
L5.pack(pady = 3)

S1 = tk.Scale(win, variable = age, from_ = 1, to = 100,
              orient = 'horizontal', length = 300, bd = 2,
              font=('Comic Sans MS', 12), fg = 'Blue')
S1.pack(pady = 3)

C1 = tk.Checkbutton(win, command = tnc, font=('Comic Sans MS', 12),
                    text = 'I Accept All Terms & Conditions.',
                    variable = tandc, fg = 'Red')
C1.pack(pady = 3)

B1 = tk.Button(win, text = 'Submit', state = 'disabled',
               font=('Comic Sans MS', 12), command = submitform)
B1.pack(pady = 3)

L6 = tk.Label(win, font=('Comic Sans MS', 12), fg = 'Blue')
L6.pack(pady = 3)

# Start GUI
win.mainloop()

# %% [markdown]
# **Output:**

# %% [markdown]
# ![P9 B1.png](data:image/png;base64,...)

# %% [markdown]
# ![P9 B2.png](data:image/png;base64,...)

# %% [markdown]
# ![P9 B3.png](data:image/png;base64,...)

# %% [markdown]
# ![P9 B4.png](data:image/png;base64,...)
